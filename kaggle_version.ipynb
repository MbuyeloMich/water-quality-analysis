# %%
# Run this in a Python cell or create convert.py
import pandas as pd

# Load and save as CSV
mhlathuze_df = pd.read_excel('data/raw/water_quality.xlsx', sheet_name='MHLATHUZE')
luvuvu_df = pd.read_excel('data/raw/water_quality.xlsx', sheet_name='LUVUVU')

mhlathuze_df.to_csv('mhlathuze_data.csv', index=False)
luvuvu_df.to_csv('luvuvu_data.csv', index=False)

print("CSV files created!")
# Out:
# CSV files created!
